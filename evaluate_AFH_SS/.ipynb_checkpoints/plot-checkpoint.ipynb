# %%
import tensorflow as tf
import numpy as np
import cv2
from matplotlib import pyplot as plt
import pandas as pd
import os
import time
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import plotly.plotly as py

# %%
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
AFH_SS_bin_score_dict = np.load('AFH_SS_bin_score_dict.npy').item()
Probability_only_bin_score_dict = np.load('Probability_only_bin_score_dict.npy').item()
SS_only_bin_score_dict = np.load('SS_only_bin_score_dict.npy').item()

# %%
trace0 = go.Bar(
    x=[key for key in AFH_SS_bin_score_dict.keys()],
    y=[AFH_SS_bin_score_dict[key][-1] for key in AFH_SS_bin_score_dict.keys()],
    name='F-scores of results using fused information',
    marker=dict(
        color='rgb(49,130,189)'
    )
)
trace1 = go.Bar(
    x=[key for key in Probability_only_bin_score_dict.keys()],
    y=[Probability_only_bin_score_dict[key][-1] for key in Probability_only_bin_score_dict.keys()],
    name='F-scores of results using only temporal consistency',
    marker=dict(
        color='rgb(245,130,45)'
    )
)

trace2 = go.Bar(
    x=[key for key in SS_only_bin_score_dict.keys()],
    y=[SS_only_bin_score_dict[key][-1] for key in SS_only_bin_score_dict.keys()],
    name='F-scores of results using only semantic information',
    marker=dict(
        color='rgb(45,230,45)'
    )
)

data = [trace0, trace1, trace2]
layout = go.Layout(
    xaxis=dict(tickangle=-45),
    barmode='group',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="892ddb69-eb91-43c8-a094-1d1aa4c62b83" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("892ddb69-eb91-43c8-a094-1d1aa4c62b83", [{"marker": {"color": "rgb(49,130,189)"}, "name": "F-scores of results using fused information", "x": ["dynamicBackground/overpass", "dynamicBackground/canoe", "dynamicBackground/fountain01", "dynamicBackground/fall", "dynamicBackground/boats", "dynamicBackground/fountain02", "cameraJitter/traffic", "cameraJitter/badminton", "cameraJitter/sidewalk", "cameraJitter/boulevard", "lowFramerate/tunnelExit_0_35fps", "lowFramerate/tramCrossroad_1fps", "lowFramerate/port_0_17fps", "lowFramerate/turnpike_0_5fps", "baseline/pedestrians", "baseline/office", "baseline/PETS2006", "baseline/highway", "intermittentObjectMotion/sofa", "intermittentObjectMotion/abandonedBox", "intermittentObjectMotion/winterDriveway", "intermittentObjectMotion/tramstop", "intermittentObjectMotion/parking", "intermittentObjectMotion/streetLight", "turbulence/turbulence3", "turbulence/turbulence1", "turbulence/turbulence0", "turbulence/turbulence2", "thermal/corridor", "thermal/library", "thermal/park", "thermal/diningRoom", "thermal/lakeSide", "PTZ/intermittentPan", "PTZ/continuousPan", "PTZ/twoPositionPTZCam", "PTZ/zoomInZoomOut", "shadow/backdoor", "shadow/copyMachine", "shadow/peopleInShade", "shadow/cubicle", "shadow/bungalows", "shadow/busStation", "badWeather/wetSnow", "badWeather/skating", "badWeather/snowFall", "badWeather/blizzard", "nightVideos/busyBoulvard", "nightVideos/tramStation", "nightVideos/fluidHighway", "nightVideos/bridgeEntry", "nightVideos/winterStreet", "nightVideos/streetCornerAtNight"], "y": [0.887849613399545, 0.9440689388902976, 0.7813707137803878, 0.9565621547385282, 0.9319507286700253, 0.939766193214272, 0.9457170959385542, 0.808400405346785, 0.7863761754157848, 0.8898870066428141, 0.8747726851943124, 0.8980251898521213, 0.026377877921329902, 0.8974832078465192, 0.6964444315021621, 0.9400755510565284, 0.8783091998739972, 0.966984576975072, 0.8281835677137456, 0.9188282132418779, 0.5460958020968755, 0.5060207362031875, 0.7720623987034037, 0.9767512885227817, 0.7826780261427005, 0.6325698871692119, 0.9002062529712032, 0.7796858249370029, 0.864286357437557, 0.9469043916122185, 0.7850666744422209, 0.9365245868849643, 0.7322574739686476, 0.3707329452097642, 0.40775772816899897, 0.7636855916648734, 0.7030123155442138, 0.8698119685608837, 0.906370692378753, 0.9486487422446498, 0.916193603850606, 0.9454120459666214, 0.9090353035121369, 0.7400957625988662, 0.9323911430133959, 0.7744641209008545, 0.7454617112169161, 0.4162524218226849, 0.7296618561540141, 0.6006999968889027, 0.5078096621867054, 0.700834055269102, 0.6983686173344924], "type": "bar", "uid": "ecc426db-7c12-46fa-a524-e599ab391364"}, {"marker": {"color": "rgb(245,130,45)"}, "name": "F-scores of results using only temporal consistency", "x": ["dynamicBackground/overpass", "dynamicBackground/canoe", "dynamicBackground/fountain01", "dynamicBackground/fall", "dynamicBackground/boats", "dynamicBackground/fountain02", "cameraJitter/traffic", "cameraJitter/badminton", "cameraJitter/sidewalk", "cameraJitter/boulevard", "lowFramerate/tunnelExit_0_35fps", "lowFramerate/tramCrossroad_1fps", "lowFramerate/port_0_17fps", "lowFramerate/turnpike_0_5fps", "baseline/pedestrians", "baseline/office", "baseline/PETS2006", "baseline/highway", "intermittentObjectMotion/sofa", "intermittentObjectMotion/abandonedBox", "intermittentObjectMotion/winterDriveway", "intermittentObjectMotion/tramstop", "intermittentObjectMotion/parking", "intermittentObjectMotion/streetLight", "turbulence/turbulence3", "turbulence/turbulence1", "turbulence/turbulence0", "turbulence/turbulence2", "thermal/corridor", "thermal/library", "thermal/park", "thermal/diningRoom", "thermal/lakeSide", "PTZ/intermittentPa ...

# %%
print(np.mean([AFH_SS_bin_score_dict[key][-1] for key in AFH_SS_bin_score_dict.keys()]))
print(np.mean([Probability_only_bin_score_dict[key][-1] for key in Probability_only_bin_score_dict.keys()]))
print(np.mean([SS_only_bin_score_dict[key][-1] for key in SS_only_bin_score_dict.keys()]))
# Out:
# 0.7838725191093223
# 0.7357045163605542
# 0.7278417565514889

# %%
trace0 = go.Bar(
    x=[key for key in AFH_SS_bin_score_dict.keys()],
    y=[AFH_SS_bin_score_dict[key][0] for key in AFH_SS_bin_score_dict.keys()],
    name='Recall of results using fused information',
    marker=dict(
        color='rgb(49,130,189)'
    )
)
trace1 = go.Bar(
    x=[key for key in Probability_only_bin_score_dict.keys()],
    y=[Probability_only_bin_score_dict[key][0] for key in Probability_only_bin_score_dict.keys()],
    name='Recall of results using only temporal consistency',
    marker=dict(
        color='rgb(245,130,45)'
    )
)

trace2 = go.Bar(
    x=[key for key in SS_only_bin_score_dict.keys()],
    y=[SS_only_bin_score_dict[key][0] for key in SS_only_bin_score_dict.keys()],
    name='Recall of results using only semantic information',
    marker=dict(
        color='rgb(45,230,45)'
    )
)

data = [trace0, trace1, trace2]
layout = go.Layout(
    xaxis=dict(tickangle=-45),
    barmode='group',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="9938f26f-9b99-40d2-b05a-9482012a2832" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9938f26f-9b99-40d2-b05a-9482012a2832", [{"marker": {"color": "rgb(49,130,189)"}, "name": "Recall of results using fused information", "x": ["dynamicBackground/overpass", "dynamicBackground/canoe", "dynamicBackground/fountain01", "dynamicBackground/fall", "dynamicBackground/boats", "dynamicBackground/fountain02", "cameraJitter/traffic", "cameraJitter/badminton", "cameraJitter/sidewalk", "cameraJitter/boulevard", "lowFramerate/tunnelExit_0_35fps", "lowFramerate/tramCrossroad_1fps", "lowFramerate/port_0_17fps", "lowFramerate/turnpike_0_5fps", "baseline/pedestrians", "baseline/office", "baseline/PETS2006", "baseline/highway", "intermittentObjectMotion/sofa", "intermittentObjectMotion/abandonedBox", "intermittentObjectMotion/winterDriveway", "intermittentObjectMotion/tramstop", "intermittentObjectMotion/parking", "intermittentObjectMotion/streetLight", "turbulence/turbulence3", "turbulence/turbulence1", "turbulence/turbulence0", "turbulence/turbulence2", "thermal/corridor", "thermal/library", "thermal/park", "thermal/diningRoom", "thermal/lakeSide", "PTZ/intermittentPan", "PTZ/continuousPan", "PTZ/twoPositionPTZCam", "PTZ/zoomInZoomOut", "shadow/backdoor", "shadow/copyMachine", "shadow/peopleInShade", "shadow/cubicle", "shadow/bungalows", "shadow/busStation", "badWeather/wetSnow", "badWeather/skating", "badWeather/snowFall", "badWeather/blizzard", "nightVideos/busyBoulvard", "nightVideos/tramStation", "nightVideos/fluidHighway", "nightVideos/bridgeEntry", "nightVideos/winterStreet", "nightVideos/streetCornerAtNight"], "y": [0.999805348320333, 0.9901549691432274, 0.8051688321742384, 0.9339706039859731, 0.8898430603584742, 0.9235225218819814, 0.9036303340086992, 0.9991711118282195, 0.9180407076279247, 0.81137817576632, 0.7964073357381493, 0.8706756175278636, 0.7530955864689568, 0.8534569403227655, 0.9982008222257335, 0.9943715030176714, 0.9856466922388065, 0.9373998029967473, 0.7779834828413195, 0.9856803152762007, 0.7418560249938528, 0.3501433536806792, 0.6763180428677277, 0.9708771606295526, 0.6469057301597654, 0.4729967631117961, 0.8324373304369966, 0.6582680952253721, 0.9983841944574442, 0.9517297459953408, 0.9788767746599603, 0.9266583645851658, 0.8024481278255202, 0.2773181332044021, 0.6395079182119734, 0.6224659602488443, 0.9992706053975201, 0.9991731687837135, 0.9989840792171993, 0.9996061447935685, 0.9961203613272543, 0.9021293875179666, 0.9774516138978975, 0.6390404901990286, 0.9968421535709867, 0.6360825001434219, 0.5973105414351334, 0.3121355136610628, 0.8672457356710126, 0.4843540008817474, 0.3710755622280155, 0.5792491962822581, 0.5975332779713457], "type": "bar", "uid": "e0a3d249-babe-4ddf-a986-d37ef2c01a74"}, {"marker": {"color": "rgb(245,130,45)"}, "name": "Recall of results using only temporal consistency", "x": ["dynamicBackground/overpass", "dynamicBackground/canoe", "dynamicBackground/fountain01", "dynamicBackground/fall", "dynamicBackground/boats", "dynamicBackground/fountain02", "cameraJitter/traffic", "cameraJitter/badminton", "cameraJitter/sidewalk", "cameraJitter/boulevard", "lowFramerate/tunnelExit_0_35fps", "lowFramerate/tramCrossroad_1fps", "lowFramerate/port_0_17fps", "lowFramerate/turnpike_0_5fps", "baseline/pedestrians", "baseline/office", "baseline/PETS2006", "baseline/highway", "intermittentObjectMotion/sofa", "intermittentObjectMotion/abandonedBox", "intermittentObjectMotion/winterDriveway", "intermittentObjectMotion/tramstop", "intermittentObjectMotion/parking", "intermittentObjectMotion/streetLight", "turbulence/turbulence3", "turbulence/turbulence1", "turbulence/turbulence0", "turbulence/turbulence2", "thermal/corridor", "thermal/library", "thermal/park", "thermal/diningRoom", "thermal/lakeSide", "PTZ/intermittentPan" ...

# %%
print(np.mean([AFH_SS_bin_score_dict[key][0] for key in AFH_SS_bin_score_dict.keys()]))
print(np.mean([Probability_only_bin_score_dict[key][0] for key in Probability_only_bin_score_dict.keys()]))
print(np.mean([SS_only_bin_score_dict[key][0] for key in SS_only_bin_score_dict.keys()]))
# Out:
# 0.8043094305098702
# 0.6791929054346862
# 0.9470965996837747

# %%
trace0 = go.Bar(
    x=[key for key in AFH_SS_bin_score_dict.keys()],
    y=[AFH_SS_bin_score_dict[key][-2] for key in AFH_SS_bin_score_dict.keys()],
    name='Precision of results using fused information',
    marker=dict(
        color='rgb(49,130,189)'
    )
)
trace1 = go.Bar(
    x=[key for key in Probability_only_bin_score_dict.keys()],
    y=[Probability_only_bin_score_dict[key][-2] for key in Probability_only_bin_score_dict.keys()],
    name='Precision of results using only temporal consistency',
    marker=dict(
        color='rgb(245,130,45)'
    )
)

trace2 = go.Bar(
    x=[key for key in SS_only_bin_score_dict.keys()],
    y=[SS_only_bin_score_dict[key][-2] for key in SS_only_bin_score_dict.keys()],
    name='Precision of results using only semantic information',
    marker=dict(
        color='rgb(45,230,45)'
    )
)

data = [trace0, trace1, trace2]
layout = go.Layout(
    xaxis=dict(tickangle=-45),
    barmode='group',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="4c7575be-d7ac-448e-9100-709a9c9ca24a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4c7575be-d7ac-448e-9100-709a9c9ca24a", [{"marker": {"color": "rgb(49,130,189)"}, "name": "Precision of results using fused information", "x": ["dynamicBackground/overpass", "dynamicBackground/canoe", "dynamicBackground/fountain01", "dynamicBackground/fall", "dynamicBackground/boats", "dynamicBackground/fountain02", "cameraJitter/traffic", "cameraJitter/badminton", "cameraJitter/sidewalk", "cameraJitter/boulevard", "lowFramerate/tunnelExit_0_35fps", "lowFramerate/tramCrossroad_1fps", "lowFramerate/port_0_17fps", "lowFramerate/turnpike_0_5fps", "baseline/pedestrians", "baseline/office", "baseline/PETS2006", "baseline/highway", "intermittentObjectMotion/sofa", "intermittentObjectMotion/abandonedBox", "intermittentObjectMotion/winterDriveway", "intermittentObjectMotion/tramstop", "intermittentObjectMotion/parking", "intermittentObjectMotion/streetLight", "turbulence/turbulence3", "turbulence/turbulence1", "turbulence/turbulence0", "turbulence/turbulence2", "thermal/corridor", "thermal/library", "thermal/park", "thermal/diningRoom", "thermal/lakeSide", "PTZ/intermittentPan", "PTZ/continuousPan", "PTZ/twoPositionPTZCam", "PTZ/zoomInZoomOut", "shadow/backdoor", "shadow/copyMachine", "shadow/peopleInShade", "shadow/cubicle", "shadow/bungalows", "shadow/busStation", "badWeather/wetSnow", "badWeather/skating", "badWeather/snowFall", "badWeather/blizzard", "nightVideos/busyBoulvard", "nightVideos/tramStation", "nightVideos/fluidHighway", "nightVideos/bridgeEntry", "nightVideos/winterStreet", "nightVideos/streetCornerAtNight"], "y": [0.7984420442143539, 0.9020821909196008, 0.7589389959136019, 0.9802737184288279, 0.9782414374615884, 0.9565915090061281, 0.991915769528237, 0.6787981726368221, 0.6877410087525544, 0.9852163978785918, 0.970243240509496, 0.9271486884308188, 0.013424033633072522, 0.9462987977846818, 0.534780219867977, 0.8914020686120471, 0.7920540569694298, 0.9984976266998224, 0.8853089232868547, 0.8604683979493304, 0.4320791815636152, 0.9120475220124427, 0.8993858008484327, 0.9826969299290992, 0.9905806705782486, 0.9546296826102457, 0.9799872497953447, 0.9560248736430574, 0.7619457216687205, 0.9421277203523443, 0.6553186111605178, 0.946603163409847, 0.6733583831095984, 0.5590490025553623, 0.2992962629621754, 0.9877857900689044, 0.5422492271156706, 0.7701074993737642, 0.829472328135001, 0.9026346996306936, 0.8481404650084872, 0.9930572721679951, 0.8495700115448955, 0.8791155282298809, 0.8757681914734196, 0.9897974761502113, 0.9913455366790975, 0.6245939548836869, 0.6297546605580128, 0.7906117338994901, 0.8041076217412331, 0.8870203119624426, 0.8401454016851987], "type": "bar", "uid": "64306d97-7d6d-4d72-8743-dfac052b72e4"}, {"marker": {"color": "rgb(245,130,45)"}, "name": "Precision of results using only temporal consistency", "x": ["dynamicBackground/overpass", "dynamicBackground/canoe", "dynamicBackground/fountain01", "dynamicBackground/fall", "dynamicBackground/boats", "dynamicBackground/fountain02", "cameraJitter/traffic", "cameraJitter/badminton", "cameraJitter/sidewalk", "cameraJitter/boulevard", "lowFramerate/tunnelExit_0_35fps", "lowFramerate/tramCrossroad_1fps", "lowFramerate/port_0_17fps", "lowFramerate/turnpike_0_5fps", "baseline/pedestrians", "baseline/office", "baseline/PETS2006", "baseline/highway", "intermittentObjectMotion/sofa", "intermittentObjectMotion/abandonedBox", "intermittentObjectMotion/winterDriveway", "intermittentObjectMotion/tramstop", "intermittentObjectMotion/parking", "intermittentObjectMotion/streetLight", "turbulence/turbulence3", "turbulence/turbulence1", "turbulence/turbulence0", "turbulence/turbulence2", "thermal/corridor", "thermal/library", "thermal/park", "thermal/diningRoom", "thermal/lakeSide", "PTZ/intermitte ...

# %%
print(np.mean([AFH_SS_bin_score_dict[key][-2] for key in AFH_SS_bin_score_dict.keys()]))
print(np.mean([Probability_only_bin_score_dict[key][-2] for key in Probability_only_bin_score_dict.keys()]))
print(np.mean([SS_only_bin_score_dict[key][-2] for key in SS_only_bin_score_dict.keys()]))
# Out:
# 0.8210995431130371
# 0.8691277829045152
# 0.6511094915864541

# %%
trace0 = go.Bar(
    x=[key for key in AFH_SS_bin_score_dict.keys()],
    y=[AFH_SS_bin_score_dict[key][-2] for key in AFH_SS_bin_score_dict.keys()],
    name='Debug of results using fused information',
    marker=dict(
        color='rgb(49,130,189)'
    )
)
trace1 = go.Bar(
    x=[key for key in Probability_only_bin_score_dict.keys()],
    y=[Probability_only_bin_score_dict[key][-2] for key in Probability_only_bin_score_dict.keys()],
    name='Debug of results using only temporal consistency',
    marker=dict(
        color='rgb(245,130,45)'
    )
)

trace2 = go.Bar(
    x=[key for key in SS_only_bin_score_dict.keys()],
    y=[SS_only_bin_score_dict[key][-2] for key in SS_only_bin_score_dict.keys()],
    name='Debug of results using only semantic information',
    marker=dict(
        color='rgb(45,230,45)'
    )
)

data = [trace0, trace1, trace2]
layout = go.Layout(
    xaxis=dict(tickangle=-45),
    barmode='group',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
